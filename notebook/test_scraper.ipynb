# %% [markdown]
# # Bachtrack Scraper Test - Freetext Search
# Testing the scraper functionality with the input string "gianni schicchi"

# %% [markdown]
# ## 1. Import Required Libraries
# Import the necessary libraries for web scraping and data processing

# %%
import sys
from pathlib import Path

# Add parent directory to path for imports
sys.path.insert(0, str(Path('.').resolve().parent))

from bachtrackapi.scraper import BachtrackScraper
import pandas as pd
import json

print("✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %%
bs = BachtrackScraper()
result = bs.search_operas('gianni schicchi')
pd.DataFrame(result).head()
# Out:
#                             title        city       date               venue  \
# 0  Suor Angelica, Gianni Schicchi      Berlin 2026-04-05       Deutsche Oper
# 1  Suor Angelica, Gianni Schicchi      Berlin 2026-04-10       Deutsche Oper
# 2  Suor Angelica, Gianni Schicchi      Berlin 2026-04-15       Deutsche Oper
# 3  Suor Angelica, Gianni Schicchi      Berlin 2026-04-17       Deutsche Oper
# 4                 Gianni Schicchi  Winterthur 2026-05-02  Theater Winterthur
#
#                                           detail_url
# 0  https://bachtrack.com/opera-event/suor-angelic...
# 1  https://bachtrack.com/opera-event/suor-angelic...
# 2  https://bachtrack.com/opera-event/suor-angelic...
# 3  https://bachtrack.com/opera-event/suor-angelic...
# 4  https://bachtrack.com/opera-event/gianni-schic...
