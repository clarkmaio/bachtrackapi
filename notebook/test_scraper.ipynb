# %% [markdown]
# # Bachtrack Scraper Test - Freetext Search
# Testing the scraper functionality with the input string "gianni schicchi"

# %% [markdown]
# ## 1. Import Required Libraries
# Import the necessary libraries for web scraping and data processing

# %%
import sys
from pathlib import Path

# Add parent directory to path for imports
sys.path.insert(0, str(Path('.').resolve().parent))

from scrapers.bachtrack.scraper import BachtrackScraper
import pandas as pd
import json

print("✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %%
bs = BachtrackScraper()
result = bs.search_operas('il barbiere di siviglia')
pd.DataFrame(result)
# Out:
#                       title               city                date  \
# 0   Il barbiere di Siviglia            Toronto 2026-02-05 00:00:00
# 1   Il barbiere di Siviglia            Toronto 2026-02-07 00:00:00
# 2   Il barbiere di Siviglia            Toronto 2026-02-11 00:00:00
# 3   Il barbiere di Siviglia            Toronto 2026-02-13 00:00:00
# 4   Il barbiere di Siviglia            Toronto 2026-02-17 00:00:00
# 5   Il barbiere di Siviglia            Toronto 2026-02-19 00:00:00
# 6   Il barbiere di Siviglia            Toronto 2026-02-21 00:00:00
# 7   Il barbiere di Siviglia               Oslo 2026-02-06 00:00:00
# 8   Il barbiere di Siviglia               Oslo 2026-02-09 00:00:00
# 9   Il barbiere di Siviglia               Oslo 2026-02-11 00:00:00
# 10  Il barbiere di Siviglia               Oslo 2026-02-14 00:00:00
# 11  Il barbiere di Siviglia               Oslo 2026-02-16 00:00:00
# 12  Il barbiere di Siviglia               Oslo 2026-02-21 00:00:00
# ...
